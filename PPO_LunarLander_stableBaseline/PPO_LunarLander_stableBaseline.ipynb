# %% [markdown]
# # Working with stable_baseline & gym library
#
# in this notebook we're going to work with `stable_baseline` and `gym` library in order to train an agent which can land safly on earth in `Lunar-Lander` environment by using `PPO` algorithm.
#
# - this mini project is for hugging face [deep-RL course](https://huggingface.co/deep-rl-course/unit0/introduction?fw=pt).

# %% [markdown]
# ## Installing and Importing libraries

# %%
! pip install -q stable-baselines3
! pip install -q box2d
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.8/171.8 KB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 28.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for gym (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.3 MB/s eta 0:00:00

# %%
import gym

from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %% [markdown]
# ## Create Environment
#
# stacking 16 lunar lander environment to train a Neral Net using these environments' observations.

# %%
# Create the environment
env = make_vec_env('LunarLander-v2', n_envs=16)

# %% [markdown]
# ## Create Model
#
# we use PPO algorithm [1] for training the agent and because the input of neural net which is observation we set the parameter `policy` equal to `MlpPolicy`.

# %%
model = PPO(
    policy = 'MlpPolicy',
    env = env,
    n_steps = 1024,
    batch_size = 64,
    n_epochs = 4,
    gamma = 0.999,
    gae_lambda = 0.98,
    ent_coef = 0.01,
    verbose=1)
# Out:
# Using cuda device

# %% [markdown]
# ## Train Agent with PPO Algorithm
#
# we train agent for 1 milion timesteps.

# %%
model.learn(total_timesteps=1000000)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.8     |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    fps             | 1773     |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 16384    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 104          |
# |    ep_rew_mean          | -141         |
# | time/                   |              |
# |    fps                  | 1682         |
# |    iterations           | 2            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0068200324 |
# |    clip_fraction        | 0.0493       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.00182     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.38e+03     |
# |    n_updates            | 4            |
# |    policy_gradient_loss | -0.00486     |
# |    value_loss           | 5.38e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.8         |
# |    ep_rew_mean          | -124         |
# | time/                   |              |
# |    fps                  | 1699         |
# |    iterations           | 3            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0066367993 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.00557      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 763          |
# |    n_updates            | 8            |
# |    policy_gradient_loss | -0.00413     |
# |    value_loss           | 2.14e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | -110        |
# | time/                   |             |
# |    fps                  | 1721        |
# |    iterations           | 4           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.006731072 |
# |    clip_fraction        | 0.042       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -0.0154     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 358         |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00462    |
# |    value_loss           | 1.04e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | -90.8       |
# | time/                   |             |
# |    fps                  | 1724        |
# |    iterations           | 5           |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008041734 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.0139      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 264         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.0049     |
# |    value_loss           | 617         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 110        |
# |    ep_rew_mean          | -71.5      |
# | time/                   |            |
# |    fps                  | 1717       |
# |    iterations           | 6          |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.00862671 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.31      |
# |    explained_variance   | 0.00672    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 173        |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00697   |
# |    value_loss           | 429        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 107         |
# |    ep_rew_mean          | -54.1       |
# | time/                   |             |
# |    fps                  | 1725        |
# |    iterations           | 7           |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.009237022 |
# |    clip_fraction        | 0.0941      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.0207      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 160         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00779    |
# |    value_loss           | 336         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 116         |
# |    ep_rew_mean          | -40         |
# | time/                   |             |
# |    fps                  | 1730        |
# |    iterations           | 8           |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.008737801 |
# |    clip_fraction        | 0.0745      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.0651     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 173         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.00556    |
# |    value_loss           | 357         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 136          |
# |    ep_rew_mean          | -22.7        |
# | time/                   |              |
# |    fps                  | 1702         |
# |    iterations           | 9            |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 147456       |
# | train/                  |              |
# |    approx_kl            | 0.0049938043 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | -0.000396    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 179          |
# |    n_updates            | 32           |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 447          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 186          |
# |    ep_rew_mean          | -7.71        |
# | time/                   |              |
# |    fps                  | 1585         |
# |    iterations           | 10           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 0.0088938605 |
# |    clip_fraction        | 0.0631       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | -0.000287    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 273          |
# |    n_updates            | 36           |
# |    policy_gradient_loss | -0.00325     |
# |    value_loss           | 487          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 230          |
# |    ep_rew_mean          | -2.25        |
# | time/                   |              |
# |    fps                  | 1483         |
# |    iterations           | 11           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0072035906 |
# |    clip_fraction        | 0.0617       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | -1e-05       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 243          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00303     |
# |    value_loss           | 489          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 301         |
# |    ep_rew_mean          | -0.532      |
# | time/                   |             |
# |    fps                  | 1365        |
# |    iterations           | 12          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.008750426 |
# |    clip_fraction        | 0.0697      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.000227    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 257         |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.00138    |
# |    value_loss           | 512         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 368          |
# |    ep_rew_mean          | -4.53        |
# | time/                   |              |
# |    fps                  | 1286         |
# |    iterations           | 13           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0058796434 |
# |    clip_fraction        | 0.0179       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.00444      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 141          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.00241     |
# |    value_loss           | 347          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 397         |
# |    ep_rew_mean          | -11.6       |
# | time/                   |             |
# |    fps                  | 1217        |
# |    iterations           | 14          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 229376      |
# | train/                  |             |
# |    approx_kl            | 0.005433463 |
# |    clip_fraction        | 0.015       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 173         |
# |    n_updates            | 52          |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 287         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 503          |
# |    ep_rew_mean          | -4.2         |
# | time/                   |              |
# |    fps                  | 1148         |
# |    iterations           | 15           |
# |    time_elapsed         | 213          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0029497247 |
# |    clip_fraction        | 0.00995      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 202          |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00186     |
# |    value_loss           | 285          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 557         |
# |    ep_rew_mean          | 3.06        |
# | time/                   |             |
# |    fps                  | 1102        |
# |    iterations           | 16          |
# |    time_elapsed         | 237         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.005272495 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.663       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 109         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00113    |
# |    value_loss           | 170         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 624         |
# |    ep_rew_mean          | 17.6        |
# | time/                   |             |
# |    fps                  | 1062        |
# |    iterations           | 17          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.005634702 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 64          |
# |    policy_gradient_loss | -0.000879   |
# |    value_loss           | 159         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 671          |
# |    ep_rew_mean          | 31.6         |
# | time/                   |              |
# |    fps                  | 1031         |
# |    iterations           | 18           |
# |    time_elapsed         | 286          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0068259565 |
# |    clip_fraction        | 0.0412       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.851        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42           |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.00317     |
# |    value_loss           | 89           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 729         |
# |    ep_rew_mean          | 45.9        |
# | time/                   |             |
# |    fps                  | 1002        |
# |    iterations           | 19          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.005207341 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.3        |
# |    n_updates            | 72          |
# |    policy_gradient_loss | -0.00157    |
# |    value_loss           | 110         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 729          |
# |    ep_rew_mean          | 56.5         |
# | time/                   |              |
# |    fps                  | 986          |
# |    iterations           | 20           |
# |    time_elapsed         | 332          |
# |    total_timesteps      | 327680       |
# | train/                  |              |
# |    approx_kl            | 0.0066848034 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.915        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.9         |
# |    n_updates            | 76           |
# |    policy_gradient_loss | -0.00229     |
# |    value_loss           | 61           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 768          |
# |    ep_rew_mean          | 64.4         |
# | time/                   |              |
# |    fps                  | 969          |
# |    iterations           | 21           |
# |    time_elapsed         | 354          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0051240283 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.878        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51.4         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 121          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 804          |
# |    ep_rew_mean          | 73.8         |
# | time/                   |              |
# |    fps                  | 954          |
# |    iterations           | 22           |
# |    time_elapsed         | 377          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0050039208 |
# |    clip_fraction        | 0.0207       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.858        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 64.7         |
# |    n_updates            | 84           |
# |    policy_gradient_loss | -0.00101     |
# |    value_loss           | 121          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 821        |
# |    ep_rew_mean          | 79.6       |
# | time/                   |            |
# |    fps                  | 942        |
# |    iterations           | 23         |
# |    time_elapsed         | 399        |
# |    total_timesteps      | 376832     |
# | train/                  |            |
# |    approx_kl            | 0.00901503 |
# |    clip_fraction        | 0.0854     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.14      |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.1       |
# |    n_updates            | 88         |
# |    policy_gradient_loss | -0.00146   |
# |    value_loss           | 58.1       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 845        |
# |    ep_rew_mean          | 85.6       |
# | time/                   |            |
# |    fps                  | 928        |
# |    iterations           | 24         |
# |    time_elapsed         | 423        |
# |    total_timesteps      | 393216     |
# | train/                  |            |
# |    approx_kl            | 0.00589623 |
# |    clip_fraction        | 0.0283     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.13      |
# |    explained_variance   | 0.938      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 35.8       |
# |    n_updates            | 92         |
# |    policy_gradient_loss | -0.000943  |
# |    value_loss           | 54.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 891         |
# |    ep_rew_mean          | 93          |
# | time/                   |             |
# |    fps                  | 917         |
# |    iterations           | 25          |
# |    time_elapsed         | 446         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.004862607 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.941       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.94        |
# |    n_updates            | 96          |
# |    policy_gradient_loss | -0.000947   |
# |    value_loss           | 50.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 928        |
# |    ep_rew_mean          | 100        |
# | time/                   |            |
# |    fps                  | 908        |
# |    iterations           | 26         |
# |    time_elapsed         | 469        |
# |    total_timesteps      | 425984     |
# | train/                  |            |
# |    approx_kl            | 0.00822182 |
# |    clip_fraction        | 0.0471     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.9       |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.00209   |
# |    value_loss           | 37.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 915         |
# |    ep_rew_mean          | 100         |
# | time/                   |             |
# |    fps                  | 902         |
# |    iterations           | 27          |
# |    time_elapsed         | 490         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.005138023 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.93        |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 26.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 907          |
# |    ep_rew_mean          | 106          |
# | time/                   |              |
# |    fps                  | 895          |
# |    iterations           | 28           |
# |    time_elapsed         | 512          |
# |    total_timesteps      | 458752       |
# | train/                  |              |
# |    approx_kl            | 0.0025956663 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 65.4         |
# |    n_updates            | 108          |
# |    policy_gradient_loss | -0.000566    |
# |    value_loss           | 94.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 893          |
# |    ep_rew_mean          | 106          |
# | time/                   |              |
# |    fps                  | 890          |
# |    iterations           | 29           |
# |    time_elapsed         | 533          |
# |    total_timesteps      | 475136       |
# | train/                  |              |
# |    approx_kl            | 0.0054052607 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.28         |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 46.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 892         |
# |    ep_rew_mean          | 110         |
# | time/                   |             |
# |    fps                  | 887         |
# |    iterations           | 30          |
# |    time_elapsed         | 553         |
# |    total_timesteps      | 491520      |
# | train/                  |             |
# |    approx_kl            | 0.003943517 |
# |    clip_fraction        | 0.0363      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.993      |
# |    explained_variance   | 0.968       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.9        |
# |    n_updates            | 116         |
# |    policy_gradient_loss | -0.000135   |
# |    value_loss           | 39.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 856         |
# |    ep_rew_mean          | 112         |
# | time/                   |             |
# |    fps                  | 884         |
# |    iterations           | 31          |
# |    time_elapsed         | 574         |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.004436864 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.955      |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.84        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00121    |
# |    value_loss           | 29.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 841          |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 882          |
# |    iterations           | 32           |
# |    time_elapsed         | 594          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0033419621 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.95        |
# |    explained_variance   | 0.934        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 145          |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.000793    |
# |    value_loss           | 86.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 844          |
# |    ep_rew_mean          | 111          |
# | time/                   |              |
# |    fps                  | 880          |
# |    iterations           | 33           |
# |    time_elapsed         | 614          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0027427967 |
# |    clip_fraction        | 0.0192       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.913       |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37           |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.000314    |
# |    value_loss           | 60.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 837          |
# |    ep_rew_mean          | 115          |
# | time/                   |              |
# |    fps                  | 876          |
# |    iterations           | 34           |
# |    time_elapsed         | 635          |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0033345101 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.915       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.3         |
# |    n_updates            | 132          |
# |    policy_gradient_loss | -0.00035     |
# |    value_loss           | 49.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 829          |
# |    ep_rew_mean          | 115          |
# | time/                   |              |
# |    fps                  | 875          |
# |    iterations           | 35           |
# |    time_elapsed         | 655          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0054141833 |
# |    clip_fraction        | 0.0541       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.928       |
# |    explained_variance   | 0.969        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.77         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.00196     |
# |    value_loss           | 36.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 844          |
# |    ep_rew_mean          | 119          |
# | time/                   |              |
# |    fps                  | 870          |
# |    iterations           | 36           |
# |    time_elapsed         | 677          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0043982845 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.922       |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.88         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00137     |
# |    value_loss           | 32.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 881         |
# |    ep_rew_mean          | 126         |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 37          |
# |    time_elapsed         | 698         |
# |    total_timesteps      | 606208      |
# | train/                  |             |
# |    approx_kl            | 0.008172801 |
# |    clip_fraction        | 0.0851      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.95       |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.83        |
# |    n_updates            | 144         |
# |    policy_gradient_loss | -0.00087    |
# |    value_loss           | 29.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 895          |
# |    ep_rew_mean          | 130          |
# | time/                   |              |
# |    fps                  | 864          |
# |    iterations           | 38           |
# |    time_elapsed         | 719          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0055016847 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.942       |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.4         |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.00059     |
# |    value_loss           | 18.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 927          |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 861          |
# |    iterations           | 39           |
# |    time_elapsed         | 741          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0047912146 |
# |    clip_fraction        | 0.0321       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.921       |
# |    explained_variance   | 0.976        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.2         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 26.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 918          |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 859          |
# |    iterations           | 40           |
# |    time_elapsed         | 762          |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0041572507 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.884       |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71         |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 24.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 932          |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 857          |
# |    iterations           | 41           |
# |    time_elapsed         | 783          |
# |    total_timesteps      | 671744       |
# | train/                  |              |
# |    approx_kl            | 0.0030656115 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.894       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.3          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000722    |
# |    value_loss           | 45.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 940          |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 854          |
# |    iterations           | 42           |
# |    time_elapsed         | 805          |
# |    total_timesteps      | 688128       |
# | train/                  |              |
# |    approx_kl            | 0.0046232976 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.868       |
# |    explained_variance   | 0.993        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.71         |
# |    n_updates            | 164          |
# |    policy_gradient_loss | -0.000473    |
# |    value_loss           | 6.37         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 950          |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 853          |
# |    iterations           | 43           |
# |    time_elapsed         | 825          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0032604213 |
# |    clip_fraction        | 0.0301       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.848       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.64         |
# |    n_updates            | 168          |
# |    policy_gradient_loss | 0.000135     |
# |    value_loss           | 5.65         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 957         |
# |    ep_rew_mean          | 147         |
# | time/                   |             |
# |    fps                  | 850         |
# |    iterations           | 44          |
# |    time_elapsed         | 847         |
# |    total_timesteps      | 720896      |
# | train/                  |             |
# |    approx_kl            | 0.002722099 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.833      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37        |
# |    n_updates            | 172         |
# |    policy_gradient_loss | -0.000394   |
# |    value_loss           | 26.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 971          |
# |    ep_rew_mean          | 154          |
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 45           |
# |    time_elapsed         | 868          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0032976815 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.818       |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.884        |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.000294    |
# |    value_loss           | 5.3          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 984          |
# |    ep_rew_mean          | 159          |
# | time/                   |              |
# |    fps                  | 848          |
# |    iterations           | 46           |
# |    time_elapsed         | 888          |
# |    total_timesteps      | 753664       |
# | train/                  |              |
# |    approx_kl            | 0.0029752133 |
# |    clip_fraction        | 0.0291       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.81        |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.8          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000761    |
# |    value_loss           | 16           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 984          |
# |    ep_rew_mean          | 160          |
# | time/                   |              |
# |    fps                  | 846          |
# |    iterations           | 47           |
# |    time_elapsed         | 909          |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0036302574 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.833       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.06         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.00047     |
# |    value_loss           | 24.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 975          |
# |    ep_rew_mean          | 163          |
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 48           |
# |    time_elapsed         | 930          |
# |    total_timesteps      | 786432       |
# | train/                  |              |
# |    approx_kl            | 0.0045124236 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.765       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.416        |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.000557    |
# |    value_loss           | 2.74         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 964        |
# |    ep_rew_mean          | 167        |
# | time/                   |            |
# |    fps                  | 845        |
# |    iterations           | 49         |
# |    time_elapsed         | 949        |
# |    total_timesteps      | 802816     |
# | train/                  |            |
# |    approx_kl            | 0.00420657 |
# |    clip_fraction        | 0.0555     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.73      |
# |    explained_variance   | 0.96       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 114        |
# |    n_updates            | 192        |
# |    policy_gradient_loss | -0.000508  |
# |    value_loss           | 65.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 906         |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 846         |
# |    iterations           | 50          |
# |    time_elapsed         | 968         |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.004019366 |
# |    clip_fraction        | 0.0605      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.675      |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 95          |
# |    n_updates            | 196         |
# |    policy_gradient_loss | -0.00233    |
# |    value_loss           | 157         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 863         |
# |    ep_rew_mean          | 192         |
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 51          |
# |    time_elapsed         | 986         |
# |    total_timesteps      | 835584      |
# | train/                  |             |
# |    approx_kl            | 0.005825627 |
# |    clip_fraction        | 0.0705      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.688      |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 181         |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00278    |
# |    value_loss           | 244         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 710         |
# |    ep_rew_mean          | 223         |
# | time/                   |             |
# |    fps                  | 850         |
# |    iterations           | 52          |
# |    time_elapsed         | 1002        |
# |    total_timesteps      | 851968      |
# | train/                  |             |
# |    approx_kl            | 0.004120986 |
# |    clip_fraction        | 0.0553      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.684      |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.7        |
# |    n_updates            | 204         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 192         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 542          |
# |    ep_rew_mean          | 244          |
# | time/                   |              |
# |    fps                  | 853          |
# |    iterations           | 53           |
# |    time_elapsed         | 1017         |
# |    total_timesteps      | 868352       |
# | train/                  |              |
# |    approx_kl            | 0.0069805956 |
# |    clip_fraction        | 0.0697       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.677       |
# |    explained_variance   | 0.803        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 182          |
# |    n_updates            | 208          |
# |    policy_gradient_loss | -0.00437     |
# |    value_loss           | 325          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 381         |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 857         |
# |    iterations           | 54          |
# |    time_elapsed         | 1031        |
# |    total_timesteps      | 884736      |
# | train/                  |             |
# |    approx_kl            | 0.013351831 |
# |    clip_fraction        | 0.0892      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.712      |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 143         |
# |    n_updates            | 212         |
# |    policy_gradient_loss | -0.00343    |
# |    value_loss           | 262         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 342         |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 55          |
# |    time_elapsed         | 1045        |
# |    total_timesteps      | 901120      |
# | train/                  |             |
# |    approx_kl            | 0.005495752 |
# |    clip_fraction        | 0.0579      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.762      |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.3        |
# |    n_updates            | 216         |
# |    policy_gradient_loss | -0.00147    |
# |    value_loss           | 256         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | 244          |
# | time/                   |              |
# |    fps                  | 866          |
# |    iterations           | 56           |
# |    time_elapsed         | 1059         |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0031159725 |
# |    clip_fraction        | 0.0319       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | 0.788        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.2         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 290          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 336          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 870          |
# |    iterations           | 57           |
# |    time_elapsed         | 1072         |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0036190422 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.72        |
# |    explained_variance   | 0.815        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 63           |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.000366    |
# |    value_loss           | 266          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 253          |
# | time/                   |              |
# |    fps                  | 874          |
# |    iterations           | 58           |
# |    time_elapsed         | 1086         |
# |    total_timesteps      | 950272       |
# | train/                  |              |
# |    approx_kl            | 0.0034714416 |
# |    clip_fraction        | 0.0508       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.759       |
# |    explained_variance   | 0.874        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.6         |
# |    n_updates            | 228          |
# |    policy_gradient_loss | 0.000321     |
# |    value_loss           | 153          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 313          |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 879          |
# |    iterations           | 59           |
# |    time_elapsed         | 1098         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0037977197 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.747       |
# |    explained_variance   | 0.87         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.4         |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -0.000775    |
# |    value_loss           | 167          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 298          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 884          |
# |    iterations           | 60           |
# |    time_elapsed         | 1111         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0030691777 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.76        |
# |    explained_variance   | 0.799        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.6         |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -1.11e-05    |
# |    value_loss           | 259          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 289         |
# |    ep_rew_mean          | 244         |
# | time/                   |             |
# |    fps                  | 889         |
# |    iterations           | 61          |
# |    time_elapsed         | 1123        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.003124497 |
# |    clip_fraction        | 0.0238      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.704       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 148         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.000143   |
# |    value_loss           | 437         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 287          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 894          |
# |    iterations           | 62           |
# |    time_elapsed         | 1135         |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0032738198 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.73        |
# |    explained_variance   | 0.77         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 245          |
# |    n_updates            | 244          |
# |    policy_gradient_loss | -0.000627    |
# |    value_loss           | 367          |
# ------------------------------------------

# %% [markdown]
# ## Evaluate the Agent
#
# for evaluation we test our trained agent on a new environment.

# %%
eval_env = gym.make("LunarLander-v2")
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.8/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=259.40 +/- 22.087186172676166

# %% [markdown]
# ## Resources
#
# [1] J. Schulman, F. Wolski, P. Dhariwal, A. Radford, and O. Klimov, “Proximal Policy Optimization Algorithms,” arXiv [cs.LG], 2017.
